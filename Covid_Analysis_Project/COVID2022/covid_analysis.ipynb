# %%
import pandas as pd

# %%
keyindi = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_KeyIndicators",index_col="Date")
keyindi.drop("Unnamed: 0",axis=1,inplace=True)
keyindi.head()
# Out:
#                      Cumulative  Cumulative  Test positive  \
# Date
# 2020-03-11 00:00:00          48                          2
# 2020-03-11 00:00:00          61                          0
# 2020-03-11 00:00:00          84                         14
# 2020-03-11 00:00:00          20                          0
# 2020-03-11 00:00:00           3                          0
#
#                      Cumulative  tests performed  Discharged  Expired  \
# Date
# 2020-03-11 00:00:00                           80           0        0
# 2020-03-11 00:00:00                           95           0        0
# 2020-03-11 00:00:00                          171           1        0
# 2020-03-11 00:00:00                           28           0        0
# 2020-03-11 00:00:00                            0           0        0
#
#                      Home Quarantine  New  (last 24 hrs)  Region  \
# Date
# 2020-03-11 00:00:00              NaN                   3     ICT
# ...

# %%
keyindi_d = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_KeyIndicators_Detail",index_col="Date")
keyindi_d.head()
# Out:
#            Province Old  Suspected Cases Last Date  \
# Date
# 2020-04-04          AJK                        322
# 2020-04-04  Balochistan                       2171
# 2020-04-04           GB                        961
# 2020-04-04          ICT                       2395
# 2020-04-04           KP                       1938
#
#             Suspected Cases Last 24 Hrs  Suspected Cases Cumulative  \
# Date
# 2020-04-04                           21                         343
# 2020-04-04                          230                        2401
# 2020-04-04                            2                         963
# 2020-04-04                          174                        2569
# 2020-04-04                          431                        2369
#
#             Lab Tests Last 24 Hrs  Lab Tests Cumulative  \
# Date
# 2020-04-04                     21                   343
# 2020-04-04                      0                  2401
# ...

# %%
action_s = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_Action_Screen",index_col="Date")
action_s.head()
# Out:
#              Cumulative travelers Screened  Suspected at Points of Entry  \
# Date
# 11-Mar-2020                         873288                            26
# 12-Mar-2020                         894256                            29
# 13-Mar-2020                         913542                            33
# 14-Mar-2020                         933970                            43
# 15-Mar-2020                         954646                            59
#
#              Travelers Screened at Points ofEntry in last 24 hours
# Date
# 11-Mar-2020                                              21102
# 12-Mar-2020                                              20968
# 13-Mar-2020                                              19286
# 14-Mar-2020                                              20428
# 15-Mar-2020                                              20676

# %%
action_c = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_Action_Call",index_col="Date")
action_c.head()
# Out:
#                         Returnees  Advised Self-Quarantine  \
# Date
# 11-Mar-2020   Returnees from Iran                        0
# 11-Mar-2020  Returnees from China                       11
# 12-Mar-2020   Returnees from Iran                       14
# 12-Mar-2020  Returnees from China                        7
# 13-Mar-2020   Returnees from Iran                        0
#
#              Cumulative no offirst-time calls  Cumulativefollow-up calls  \
# Date
# 11-Mar-2020                              9459                       2553
# 11-Mar-2020                              5342                       7746
# 12-Mar-2020                              9475                       3221
# 12-Mar-2020                              5352                       7855
# 13-Mar-2020                              9475                       3853
#
#              First-time calls inpast 24 hrs  Follow-up calls inpast 24 hrs
# Date
# ...

# %%
news = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_COVID_News",index_col="Date")
news.drop("Unnamed: 0",axis=1,inplace=True)
news
# Out:
#                                                                   News  \
# Date
# 11-Mar-2020                                         Updates: Pakistan:
# 11-Mar-2020          Three new cases have been confirmed in the pas...
# 11-Mar-2020          Number of calls to passengers returning from I...
# 11-Mar-2020                                                    Global:
# 11-Mar-2020               Total cases: 118,887,  Total Deaths: 4,290 •
# ...                                                                ...
# 2020-04-03 00:00:00  2,450. Two deaths reported from Sindh. One dea...
# 2020-04-03 00:00:00                                       deaths 35. •
# 2020-04-03 00:00:00                                            Global:
# 2020-04-03 00:00:00       Total cases:1,015,709 Total Deaths: 53,069 •
# 2020-04-03 00:00:00  Total number of countries/regions affected: 181 •
#
#                                                               Agg News
# Date
# ...

# %%
nih_res = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_NIH_Response",index_col="Date")
nih_res.drop("Unnamed: 0",axis=1,inplace=True)
nih_res.head()
# Out:
#                                  NIH Preparedness and Response  \
# Date
# 11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 11-Mar-2020  IPC trainings have been completed at Gilgit an...
# 11-Mar-2020  Training of the GB lab staff has been conducte...
# 11-Mar-2020  IPC training is in progress for FG Hospital st...
# 12-Mar-2020          BSL-3 mobile lab is ready for testing.  •
#
#                              Agg NIH Preparedness and Response
# Date
# 11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 12-Mar-2020  BSL-3 mobile lab is ready for testing.  • \n I...

# %%
nih_ris = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_NIH_Risk",index_col="Date")
nih_ris.drop("Unnamed: 0",axis=1,inplace=True)
nih_ris.head()
# Out:
#             Risk Assessment NIH
# Date
# 11-Mar-2020           MODERATE.
# 12-Mar-2020           MODERATE.
# 13-Mar-2020           MODERATE.
# 14-Mar-2020           MODERATE.
# 15-Mar-2020            Moderate

# %%
prov_res = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_Province_Response",index_col="Date")
prov_res.drop("Unnamed: 0",axis=1,inplace=True)
prov_res.head()
# Out:
#                   region                Provinces Preparedness and Response  \
# Date
# 11-Mar-2020  Balochistan  316 newly arrived individuals screened and qua...
# 11-Mar-2020  Balochistan  14 Chinese nationals quarantined at East Bay E...
# 11-Mar-2020        Sindh  Staff deployed to designated quarantine facili...
# 11-Mar-2020        Sindh  Training and orientation sessions for the heal...
# 11-Mar-2020      KP & TD  24 High Dependency Units established across KP...
#
#                        Agg Provinces Preparedness and Response
# Date
# 11-Mar-2020  316 newly arrived individuals screened and qua...
# 11-Mar-2020  316 newly arrived individuals screened and qua...
# 11-Mar-2020  Staff deployed to designated quarantine facili...
# 11-Mar-2020  Staff deployed to designated quarantine facili...
# 11-Mar-2020  24 High Dependency Units established across KP...

# %%
help_l = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_Helpline_Calls",index_col="Date")
help_l.drop("Unnamed: 0",axis=1,inplace=True)
help_l.head()
# Out:
#             Cumulative Calls  New Calls
# Date
# 2020-03-11             12481        547
# 2020-03-12             13167        686
# 2020-03-13             13896        729
# 2020-03-14             15340       1444
# 2020-03-15             19131       3791

# %%
quarant_d = pd.read_excel("COVID_FINAL_DATA.xlsx", sheet_name="TimeSeries_Quarantine_Details",index_col="Date")
quarant_d.drop("Unnamed: 0",axis=1,inplace=True)
quarant_d.head()
# Out:
#                 Regions  Quarantine facilities (n)  \
# Date
# 2020-04-01          ICT                          1
# 2020-04-01       Punjab                          4
# 2020-04-01        Sindh                          5
# 2020-04-01           KP                         92
# 2020-04-01  Balochistan                          9
#
#             No. of arrivals in last 24 hrs  Cumulative no of persons present
# Date
# 2020-04-01                               0                                24
# 2020-04-01                               0                              2956
# 2020-04-01                               0                              1388
# 2020-04-01                             181                              3260
# 2020-04-01                               0                               366
