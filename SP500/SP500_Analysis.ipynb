# %% [markdown]
# # Import Library

# %%
import pandas as pd
import kagglehub

# %% [markdown]
# Ideas
#
# Impact of Macroeconomic Factors
#
# 	•	Objective: Assess how macroeconomic factors impact the S&P 500.
# 	•	Data: S&P 500 data along with macroeconomic indicators like unemployment rates, inflation, interest rates, and GDP growth.
# 	•	Analysis Ideas:
# 	•	Perform regression analysis to measure the relationship between the S&P 500 index and macroeconomic factors.
# 	•	Use factor analysis to understand which economic indicators are most correlated with changes in the index.
# 	•	Explore the impact of Federal Reserve policy changes (interest rate hikes or cuts) on the market’s performance.

# %% [markdown]
# # Import Data

# %%
companies = kagglehub.dataset_download("andrewmvd/sp-500-stocks",path="sp500_companies.csv")
index_ = kagglehub.dataset_download("andrewmvd/sp-500-stocks",path="sp500_index.csv")
stocks = kagglehub.dataset_download("andrewmvd/sp-500-stocks",path="sp500_stocks.csv")

# %%
companies = pd.read_csv(companies)
companies
# Out:
#     Exchange Symbol               Shortname                Longname  \
# 0        NMS   AAPL              Apple Inc.              Apple Inc.
# 1        NMS   NVDA      NVIDIA Corporation      NVIDIA Corporation
# 2        NMS   MSFT   Microsoft Corporation   Microsoft Corporation
# 3        NMS   GOOG           Alphabet Inc.           Alphabet Inc.
# 4        NMS  GOOGL           Alphabet Inc.           Alphabet Inc.
# ..       ...    ...                     ...                     ...
# 498      NYQ    MOS    Mosaic Company (The)      The Mosaic Company
# 499      NYQ    BWA         BorgWarner Inc.         BorgWarner Inc.
# 500      NYQ    FMC         FMC Corporation         FMC Corporation
# 501      NMS   PARA        Paramount Global        Paramount Global
# 502      NYQ   AMTM  Amentum Holdings, Inc.  Amentum Holdings, Inc.
#
#                      Sector                        Industry  Currentprice  \
# 0                Technology            Consumer Electronics        235.00
# ...

# %%
index_ = pd.read_csv(index_)
index_
# Out:
#             Date   S&P500
# 0     2014-09-30  1972.29
# 1     2014-10-01  1946.16
# 2     2014-10-02  1946.17
# 3     2014-10-03  1967.90
# 4     2014-10-06  1964.82
# ...          ...      ...
# 2526  2024-10-14  5859.85
# 2527  2024-10-15  5815.26
# 2528  2024-10-16  5842.47
# 2529  2024-10-17  5841.47
# 2530  2024-10-18  5864.67
#
# [2531 rows x 2 columns]

# %%
stocks = pd.read_csv(stocks)
stocks
# Out:
#                Date Symbol   Adj Close       Close        High         Low  \
# 0        2010-01-04    MMM   44.016731   69.414719   69.774246   69.122070
# 1        2010-01-05    MMM   43.741020   68.979935   69.590302   68.311035
# 2        2010-01-06    MMM   44.361351   69.958191   70.735786   69.824417
# 3        2010-01-07    MMM   44.393177   70.008362   70.033447   68.662209
# 4        2010-01-08    MMM   44.705978   70.501671   70.501671   69.648827
# ...             ...    ...         ...         ...         ...         ...
# 1873167  2024-10-14    ZTS  192.649994  192.649994  193.039993  189.789993
# 1873168  2024-10-15    ZTS  192.389999  192.389999  195.820007  191.940002
# 1873169  2024-10-16    ZTS  194.440002  194.440002  195.880005  191.759995
# 1873170  2024-10-17    ZTS  191.000000  191.000000  196.550003  190.889999
# 1873171  2024-10-18    ZTS  193.279999  193.279999  193.485001  190.580002
#
#                Open     Volume
# 0         69.473244  3640265.0
# ...

# %% [markdown]
# # Do it have any NULL ?

# %%
companies.isnull().any()
# Out:
# Exchange               False
# Symbol                 False
# Shortname              False
# Longname               False
# Sector                 False
# Industry               False
# Currentprice           False
# Marketcap              False
# Ebitda                  True
# Revenuegrowth           True
# City                   False
# State                   True
# Country                False
# Fulltimeemployees       True
# Longbusinesssummary    False
# Weight                 False
# dtype: bool

# %%
index_.isnull().any()
# Out:
# Date      False
# S&P500    False
# dtype: bool

# %%
stocks.isnull().any()
# Out:
# Date         False
# Symbol       False
# Adj Close     True
# Close         True
# High          True
# Low           True
# Open          True
# Volume        True
# dtype: bool

# %%
stocks.groupby(by="Symbol")["Symbol"].count()
# Out:
# Symbol
# A       3724
# AAPL    3724
# ABBV    3724
# ABNB    3724
# ABT     3724
#         ...
# XYL     3724
# YUM     3724
# ZBH     3724
# ZBRA    3724
# ZTS     3724
# Name: Symbol, Length: 503, dtype: int64

# %%
companies.groupby(by="Symbol")["Symbol"].count()
# Out:
# Symbol
# A       1
# AAPL    1
# ABBV    1
# ABNB    1
# ABT     1
#        ..
# XYL     1
# YUM     1
# ZBH     1
# ZBRA    1
# ZTS     1
# Name: Symbol, Length: 503, dtype: int64

# %%
companies.groupby(by="Sector")["Sector"].count()
# Out:
# Sector
# Basic Materials           22
# Communication Services    22
# Consumer Cyclical         55
# Consumer Defensive        37
# Energy                    22
# Financial Services        67
# Healthcare                63
# Industrials               70
# Real Estate               31
# Technology                82
# Utilities                 32
# Name: Sector, dtype: int64
